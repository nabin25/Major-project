# %%
import torch
from matplotlib import pyplot as plt
import numpy as np
import cv2
import torch.nn as nn

# %%
from PIL import Image
from torchvision import transforms

# %%
class HandSignClassifier(nn.Module):
    def __init__(self, num_classes):
        super(HandSignClassifier, self).__init__()
        self.features = nn.Sequential(
            nn.Conv2d(3, 64, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(64, 128, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2),
            nn.Conv2d(128, 256, kernel_size=3, padding=1),
            nn.ReLU(inplace=True),
            nn.MaxPool2d(kernel_size=2, stride=2)
        )
        self.avgpool = nn.AdaptiveAvgPool2d((7, 7))
        self.classifier = nn.Sequential(
            nn.Linear(256 * 7 * 7, 512),
            nn.ReLU(inplace=True),
            nn.Dropout(),
            nn.Linear(512, num_classes)
        )

    def forward(self, x):
        x = self.features(x)
        x = self.avgpool(x)
        x = torch.flatten(x, 1)
        x = self.classifier(x)
        return x

# %%
model = HandSignClassifier(num_classes=36)

# %%
model.load_state_dict(torch.load('../hand_sign_classifier4.pth'))
# Out:
# <All keys matched successfully>

# %%
model.eval()
# Out:
# HandSignClassifier(
#   (features): Sequential(
#     (0): Conv2d(3, 64, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (1): ReLU(inplace=True)
#     (2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (3): Conv2d(64, 128, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (4): ReLU(inplace=True)
#     (5): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (6): Conv2d(128, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (7): ReLU(inplace=True)
#     (8): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (avgpool): AdaptiveAvgPool2d(output_size=(7, 7))
#   (classifier): Sequential(
#     (0): Linear(in_features=12544, out_features=512, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Dropout(p=0.5, inplace=False)
#     (3): Linear(in_features=512, out_features=36, bias=True)
#   )
# )

# %%
pip install mediapipe
# Out:
# Collecting mediapipeNote: you may need to restart the kernel to use updated packages.
#
#   Downloading mediapipe-0.10.9-cp39-cp39-win_amd64.whl.metadata (9.8 kB)
# Collecting absl-py (from mediapipe)
#   Using cached absl_py-2.0.0-py3-none-any.whl.metadata (2.3 kB)
# Requirement already satisfied: attrs>=19.1.0 in e:\major-project\environ\lib\site-packages (from mediapipe) (23.1.0)
# Collecting flatbuffers>=2.0 (from mediapipe)
#   Using cached flatbuffers-23.5.26-py2.py3-none-any.whl.metadata (850 bytes)
# Requirement already satisfied: matplotlib in e:\major-project\environ\lib\site-packages (from mediapipe) (3.8.2)
# Requirement already satisfied: numpy in e:\major-project\environ\lib\site-packages (from mediapipe) (1.26.2)
# Collecting opencv-contrib-python (from mediapipe)
#   Downloading opencv_contrib_python-4.8.1.78-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Collecting protobuf<4,>=3.11 (from mediapipe)
#   Downloading protobuf-3.20.3-cp39-cp39-win_amd64.whl (904 kB)
#      ---------------------------------------- 0.0/904.2 kB ? eta -:--:--
#      --- ----------------------------------- 81.9/904.2 kB 1.5 MB/s eta 0:00:01
#      -------- ----------------------------- 194.6/904.2 kB 2.0 MB/s eta 0:00:01
#      --------------- ---------------------- 368.6/904.2 kB 2.6 MB/s eta 0:00:01
#      ---------------------------- --------- 686.1/904.2 kB 3.6 MB/s eta 0:00:01
#      -------------------------------------  901.1/904.2 kB 4.4 MB/s eta 0:00:01
#      -------------------------------------- 904.2/904.2 kB 3.8 MB/s eta 0:00:00
# Collecting sounddevice>=0.4.4 (from mediapipe)
#   Downloading sounddevice-0.4.6-py3-none-win_amd64.whl (199 kB)
#      ---------------------------------------- 0.0/199.7 kB ? eta -:--:--
#      -------------------------------------- 199.7/199.7 kB 6.1 MB/s eta 0:00:00
# Requirement already satisfied: CFFI>=1.0 in e:\major-project\environ\lib\site-packages (from sounddevice>=0.4.4->mediapipe) (1.16.0)
# Requirement already satisfied: contourpy>=1.0.1 in e:\major-project\environ\lib\site-packages (from matplotlib->mediapipe) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in e:\major-project\environ\lib\site-packages (from matplotlib->mediapipe) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in e:\major-project\environ\lib\site-packages (from matplotlib->mediapipe) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in e:\major-project\environ\lib\site-packages (from matplotlib->mediapipe) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in e:\major-project\environ\lib\site-packages (from matplotlib->mediapipe) (23.2)
# Requirement already satisfied: pillow>=8 in e:\major-project\environ\lib\site-packages (from matplotlib->mediapipe) (10.1.0)
# Requirement already satisfied: pyparsing>=2.3.1 in e:\major-project\environ\lib\site-packages (from matplotlib->mediapipe) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in e:\major-project\environ\lib\site-packages (from matplotlib->mediapipe) (2.8.2)
# Requirement already satisfied: importlib-resources>=3.2.0 in e:\major-project\environ\lib\site-packages (from matplotlib->mediapipe) (6.1.1)
# Requirement already satisfied: pycparser in e:\major-project\environ\lib\site-packages (from CFFI>=1.0->sounddevice>=0.4.4->mediapipe) (2.21)
# Requirement already satisfied: zipp>=3.1.0 in e:\major-project\environ\lib\site-packages (from importlib-resources>=3.2.0->matplotlib->mediapipe) (3.17.0)
# Requirement already satisfied: six>=1.5 in e:\major-project\environ\lib\site-packages (from python-dateutil>=2.7->matplotlib->mediapipe) (1.16.0)
# Downloading mediapipe-0.10.9-cp39-cp39-win_amd64.whl (50.5 MB)
#    ---------------------------------------- 0.0/50.5 MB ? eta -:--:--
#    ---------------------------------------- 0.6/50.5 MB 12.9 MB/s eta 0:00:04
#     --------------------------------------- 1.2/50.5 MB 12.2 MB/s eta 0:00:05
#    - -------------------------------------- 1.5/50.5 MB 10.8 MB/s eta 0:00:05
#    - -------------------------------------- 2.0/50.5 MB 10.4 MB/s eta 0:00:05
#    - -------------------------------------- 2.5/50.5 MB 10.5 MB/s eta 0:00:05
#    - -------------------------------------- 2.5/50.5 MB 10.5 MB/s eta 0:00:05
#    -- ------------------------------------- 2.9/50.5 MB 9.0 MB/s eta 0:00:06
#    -- ------------------------------------- 3.4/50.5 MB 9.1 MB/s eta 0:00:06
#    --- ------------------------------------ 3.9/50.5 MB 9.3 MB/s eta 0:00:06
#    --- ------------------------------------ 4.0/50.5 MB 8.4 MB/s eta 0:00:06
#    --- ------------------------------------ 4.5/50.5 MB 8.7 MB/s eta 0:00:06
#    --- ------------------------------------ 5.0/50.5 MB 8.8 MB/s eta 0:00:06
#    ---- ----------------------------------- 5.4/50.5 MB 8.9 MB/s eta 0:00:06
#    ---- ----------------------------------- 5.9/50.5 MB 9.0 MB/s eta 0:00:05
#    ----- ---------------------------------- 6.4/50.5 MB 9.0 MB/s eta 0:00:05
#    ----- ---------------------------------- 6.8/50.5 MB 9.0 MB/s eta 0:00:05
#    ----- ---------------------------------- 7.2/50.5 MB 9.1 MB/s eta 0:00:05
#    ----- ---------------------------------- 7.4/50.5 MB 8.7 MB/s eta 0:00:05
#    ------ --------------------------------- 7.8/50.5 MB 8.8 MB/s eta 0:00:05
#    ------ --------------------------------- 8.1/50.5 MB 8.6 MB/s eta 0:00:05
#    ------ --------------------------------- 8.6/50.5 MB 8.7 MB/s eta 0:00:05
#    ------ --------------------------------- 8.8/50.5 MB 8.7 MB/s eta 0:00:05
#    ------- -------------------------------- 9.3/50.5 MB 8.6 MB/s eta 0:00:05
#    ------- -------------------------------- 9.7/50.5 MB 8.7 MB/s eta 0:00:05
#    ------- -------------------------------- 10.0/50.5 MB 8.7 MB/s eta 0:00:05
#    -------- ------------------------------- 10.5/50.5 MB 8.5 MB/s eta 0:00:05
#    -------- ------------------------------- 11.0/50.5 MB 8.6 MB/s eta 0:00:05
#    -------- ------------------------------- 11.2/50.5 MB 8.4 MB/s eta 0:00:05
#    --------- ------------------------------ 11.5/50.5 MB 8.3 MB/s eta 0:00:05
#    --------- ------------------------------ 12.0/50.5 MB 8.3 MB/s eta 0:00:05
#    --------- ------------------------------ 12.3/50.5 MB 8.2 MB/s eta 0:00:05
#    ---------- ----------------------------- 12.7/50.5 MB 8.4 MB/s eta 0:00:05
#    ---------- ----------------------------- 13.1/50.5 MB 8.4 MB/s eta 0:00:05
#    ---------- ----------------------------- 13.6/50.5 MB 8.3 MB/s eta 0:00:05
#    ----------- ---------------------------- 14.0/50.5 MB 8.4 MB/s eta 0:00:05
#    ----------- ---------------------------- 14.2/50.5 MB 8.2 MB/s eta 0:00:05
#    ----------- ---------------------------- 14.3/50.5 MB 8.2 MB/s eta 0:00:05
#    ----------- ---------------------------- 14.6/50.5 MB 8.0 MB/s eta 0:00:05
#    ----------- ---------------------------- 15.1/50.5 MB 8.1 MB/s eta 0:00:05
#    ------------ --------------------------- 15.6/50.5 MB 8.0 MB/s eta 0:00:05
#    ------------ --------------------------- 16.1/50.5 MB 8.1 MB/s eta 0:00:05
#    ------------- -------------------------- 16.5/50.5 MB 8.2 MB/s eta 0:00:05
#    ------------- -------------------------- 16.7/50.5 MB 7.9 MB/s eta 0:00:05
#    ------------- -------------------------- 17.1/50.5 MB 7.8 MB/s eta 0:00:05
#    ------------- -------------------------- 17.4/50.5 MB 7.8 MB/s eta 0:00:05
#    -------------- ------------------------- 17.8/50.5 MB 7.9 MB/s eta 0:00:05
#    -------------- ------------------------- 18.1/50.5 MB 7.9 MB/s eta 0:00:05
#    -------------- ------------------------- 18.4/50.5 MB 7.9 MB/s eta 0:00:05
#    -------------- ------------------------- 18.7/50.5 MB 7.7 MB/s eta 0:00:05
#    --------------- ------------------------ 19.1/50.5 MB 7.8 MB/s eta 0:00:05
#    --------------- ------------------------ 19.6/50.5 MB 7.8 MB/s eta 0:00:04
#    --------------- ------------------------ 20.0/50.5 MB 7.9 MB/s eta 0:00:04
#    ---------------- ----------------------- 20.5/50.5 MB 7.9 MB/s eta 0:00:04
#    ---------------- ----------------------- 20.6/50.5 MB 7.6 MB/s eta 0:00:04
#    ---------------- ----------------------- 21.0/50.5 MB 7.6 MB/s eta 0:00:04
#    ---------------- ----------------------- 21.3/50.5 MB 7.7 MB/s eta 0:00:04
#    ----------------- ---------------------- 21.8/50.5 MB 7.8 MB/s eta 0:00:04
#    ----------------- ---------------------- 22.0/50.5 MB 7.8 MB/s eta 0:00:04
#    ----------------- ---------------------- 22.1/50.5 MB 7.5 MB/s eta 0:00:04
#    ----------------- ---------------------- 22.4/50.5 MB 7.4 MB/s eta 0:00:04
#    ----------------- ---------------------- 22.4/50.5 MB 7.2 MB/s eta 0:00:04
#    ----------------- ---------------------- 22.5/50.5 MB 7.1 MB/s eta 0:00:04
#    ----------------- ---------------------- 22.7/50.5 MB 6.9 MB/s eta 0:00:05
#    ------------------ --------------------- 23.1/50.5 MB 6.8 MB/s eta 0:00:05
#    ------------------ --------------------- 23.3/50.5 MB 6.7 MB/s eta 0:00:05
#    ------------------ --------------------- 23.6/50.5 MB 6.7 MB/s eta 0:00:05
#    ------------------ --------------------- 23.8/50.5 MB 6.6 MB/s eta 0:00:05
#    ------------------- -------------------- 24.1/50.5 MB 6.5 MB/s eta 0:00:05
#    ------------------- -------------------- 24.5/50.5 MB 6.6 MB/s eta 0:00:04
#    ------------------- -------------------- 24.8/50.5 MB 6.8 MB/s eta 0:00:04
#    ------------------- -------------------- 25.1/50.5 MB 6.7 MB/s eta 0:00:04
#    -------------------- ------------------- 25.6/50.5 MB 6.7 MB/s eta 0:00:04
#    -------------------- ------------------- 25.8/50.5 MB 6.5 MB/s eta 0:00:04
#    -------------------- ------------------- 26.3/50.5 MB 6.4 MB/s eta 0:00:04
#    --------------------- ------------------ 26.9/50.5 MB 6.5 MB/s eta 0:00:04
#    --------------------- ------------------ 27.5/50.5 MB 6.5 MB/s eta 0:00:04
#    ---------------------- ----------------- 28.0/50.5 MB 6.6 MB/s eta 0:00:04
#    ---------------------- ----------------- 28.2/50.5 MB 6.5 MB/s eta 0:00:04
#    ---------------------- ----------------- 28.5/50.5 MB 6.5 MB/s eta 0:00:04
#    ----------------------- ---------------- 29.1/50.5 MB 6.5 MB/s eta 0:00:04
#    ----------------------- ---------------- 29.6/50.5 MB 6.5 MB/s eta 0:00:04
#    ----------------------- ---------------- 29.8/50.5 MB 6.4 MB/s eta 0:00:04
#    ------------------------ --------------- 30.3/50.5 MB 6.4 MB/s eta 0:00:04
#    ------------------------ --------------- 30.9/50.5 MB 6.5 MB/s eta 0:00:04
#    ------------------------ --------------- 31.5/50.5 MB 6.5 MB/s eta 0:00:03
#    ------------------------- -------------- 31.9/50.5 MB 6.5 MB/s eta 0:00:03
#    ------------------------- -------------- 32.5/50.5 MB 6.8 MB/s eta 0:00:03
#    -------------------------- ------------- 33.0/50.5 MB 7.4 MB/s eta 0:00:03
#    -------------------------- ------------- 33.4/50.5 MB 7.5 MB/s eta 0:00:03
#    -------------------------- ------------- 33.8/50.5 MB 7.7 MB/s eta 0:00:03
#    --------------------------- ------------ 34.3/50.5 MB 7.8 MB/s eta 0:00:03
#    --------------------------- ------------ 34.7/50.5 MB 7.9 MB/s eta 0:00:03
#    --------------------------- ------------ 34.9/50.5 MB 7.8 MB/s eta 0:00:03
#    ---------------------------- ----------- 35.5/50.5 MB 7.9 MB/s eta 0:00:02
#    ---------------------------- ----------- 36.0/50.5 MB 8.2 MB/s eta 0:00:02
#    ---------------------------- ----------- 36.5/50.5 MB 8.2 MB/s eta 0:00:02
#    ----------------------------- ---------- 37.0/50.5 MB 8.3 MB/s eta 0:00:02
#    ----------------------------- ---------- 37.4/50.5 MB 8.4 MB/s eta 0:00:02
#    ----------------------------- ---------- 37.8/50.5 MB 8.2 MB/s eta 0:00:02
#    ------------------------------ --------- 38.5/50.5 MB 8.6 MB/s eta 0:00:02
#    ------------------------------- -------- 39.2/50.5 MB 8.7 MB/s eta 0:00:02
#    ------------------------------- -------- 39.6/50.5 MB 8.7 MB/s eta 0:00:02
#    ------------------------------- -------- 40.2/50.5 MB 9.1 MB/s eta 0:00:02
#    -------------------------------- ------- 40.6/50.5 MB 9.1 MB/s eta 0:00:02
#    -------------------------------- ------- 41.1/50.5 MB 9.1 MB/s eta 0:00:02
#    -------------------------------- ------- 41.6/50.5 MB 9.2 MB/s eta 0:00:01
#    --------------------------------- ------ 42.1/50.5 MB 9.4 MB/s eta 0:00:01
#    --------------------------------- ------ 42.5/50.5 MB 9.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 43.1/50.5 MB 9.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 43.3/50.5 MB 9.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 44.0/50.5 MB 9.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 44.8/50.5 MB 9.2 MB/s eta 0:00:01
#    ----------------------------------- ---- 45.4/50.5 MB 9.6 MB/s eta 0:00:01
#    ------------------------------------ --- 46.2/50.5 MB 9.8 MB/s eta 0:00:01
#    ------------------------------------- -- 46.9/50.5 MB 9.8 MB/s eta 0:00:01
#    ------------------------------------- -- 47.5/50.5 MB 9.9 MB/s eta 0:00:01
#    -------------------------------------- - 48.0/50.5 MB 10.2 MB/s eta 0:00:01
#    -------------------------------------- - 48.3/50.5 MB 10.2 MB/s eta 0:00:01
#    -------------------------------------- - 48.6/50.5 MB 9.8 MB/s eta 0:00:01
#    ---------------------------------------  49.4/50.5 MB 9.9 MB/s eta 0:00:01
#    ---------------------------------------  50.0/50.5 MB 10.1 MB/s eta 0:00:01
#    ---------------------------------------  50.5/50.5 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------------  50.5/50.5 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------------  50.5/50.5 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------------  50.5/50.5 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------------  50.5/50.5 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------------  50.5/50.5 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------------  50.5/50.5 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------------  50.5/50.5 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------------  50.5/50.5 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------------  50.5/50.5 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------------  50.5/50.5 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------------  50.5/50.5 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------------  50.5/50.5 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------------  50.5/50.5 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------------  50.5/50.5 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------------  50.5/50.5 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------------  50.5/50.5 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------------  50.5/50.5 MB 10.2 MB/s eta 0:00:01
#    ---------------------------------------- 50.5/50.5 MB 5.5 MB/s eta 0:00:00
# Using cached flatbuffers-23.5.26-py2.py3-none-any.whl (26 kB)
# Using cached absl_py-2.0.0-py3-none-any.whl (130 kB)
# Downloading opencv_contrib_python-4.8.1.78-cp37-abi3-win_amd64.whl (44.8 MB)
#    ---------------------------------------- 0.0/44.8 MB ? eta -:--:--
#     --------------------------------------- 0.6/44.8 MB 12.4 MB/s eta 0:00:04
#     --------------------------------------- 1.1/44.8 MB 11.3 MB/s eta 0:00:04
#    - -------------------------------------- 1.7/44.8 MB 11.8 MB/s eta 0:00:04
#    -- ------------------------------------- 2.2/44.8 MB 11.9 MB/s eta 0:00:04
#    -- ------------------------------------- 2.8/44.8 MB 12.0 MB/s eta 0:00:04
#    --- ------------------------------------ 3.5/44.8 MB 12.4 MB/s eta 0:00:04
#    --- ------------------------------------ 4.0/44.8 MB 12.1 MB/s eta 0:00:04
#    ---- ----------------------------------- 4.6/44.8 MB 12.3 MB/s eta 0:00:04
#    ---- ----------------------------------- 5.1/44.8 MB 12.1 MB/s eta 0:00:04
#    ----- ---------------------------------- 5.8/44.8 MB 12.3 MB/s eta 0:00:04
#    ----- ---------------------------------- 6.4/44.8 MB 12.3 MB/s eta 0:00:04
#    ------ --------------------------------- 6.9/44.8 MB 12.3 MB/s eta 0:00:04
#    ------ --------------------------------- 7.1/44.8 MB 11.6 MB/s eta 0:00:04
#    ------ --------------------------------- 7.6/44.8 MB 11.6 MB/s eta 0:00:04
#    ------- -------------------------------- 8.6/44.8 MB 11.7 MB/s eta 0:00:04
#    -------- ------------------------------- 9.2/44.8 MB 11.8 MB/s eta 0:00:04
#    -------- ------------------------------- 9.8/44.8 MB 11.9 MB/s eta 0:00:03
#    --------- ------------------------------ 10.4/44.8 MB 11.9 MB/s eta 0:00:03
#    --------- ------------------------------ 11.0/44.8 MB 11.9 MB/s eta 0:00:03
#    ---------- ----------------------------- 11.6/44.8 MB 11.9 MB/s eta 0:00:03
#    ---------- ----------------------------- 12.0/44.8 MB 11.5 MB/s eta 0:00:03
#    ----------- ---------------------------- 12.5/44.8 MB 11.1 MB/s eta 0:00:03
#    ------------ --------------------------- 13.5/44.8 MB 11.1 MB/s eta 0:00:03
#    ------------ --------------------------- 14.0/44.8 MB 10.7 MB/s eta 0:00:03
#    ------------ --------------------------- 14.5/44.8 MB 10.7 MB/s eta 0:00:03
#    ------------- -------------------------- 15.0/44.8 MB 10.7 MB/s eta 0:00:03
#    ------------- -------------------------- 15.6/44.8 MB 10.7 MB/s eta 0:00:03
#    -------------- ------------------------- 16.2/44.8 MB 10.7 MB/s eta 0:00:03
#    -------------- ------------------------- 16.7/44.8 MB 10.7 MB/s eta 0:00:03
#    --------------- ------------------------ 16.8/44.8 MB 10.2 MB/s eta 0:00:03
#    --------------- ------------------------ 17.4/44.8 MB 10.6 MB/s eta 0:00:03
#    ---------------- ----------------------- 18.0/44.8 MB 11.1 MB/s eta 0:00:03
#    ---------------- ----------------------- 18.5/44.8 MB 10.6 MB/s eta 0:00:03
#    ----------------- ---------------------- 19.1/44.8 MB 10.7 MB/s eta 0:00:03
#    ----------------- ---------------------- 19.7/44.8 MB 10.6 MB/s eta 0:00:03
#    ------------------ --------------------- 20.2/44.8 MB 10.6 MB/s eta 0:00:03
#    ------------------ --------------------- 20.7/44.8 MB 10.4 MB/s eta 0:00:03
#    ------------------ --------------------- 21.3/44.8 MB 10.6 MB/s eta 0:00:03
#    ------------------- -------------------- 21.8/44.8 MB 10.6 MB/s eta 0:00:03
#    -------------------- ------------------- 22.5/44.8 MB 11.3 MB/s eta 0:00:02
#    -------------------- ------------------- 22.6/44.8 MB 11.5 MB/s eta 0:00:02
#    -------------------- ------------------- 22.6/44.8 MB 10.9 MB/s eta 0:00:03
#    -------------------- ------------------- 22.6/44.8 MB 10.9 MB/s eta 0:00:03
#    -------------------- ------------------- 22.6/44.8 MB 10.9 MB/s eta 0:00:03
#    -------------------- ------------------- 22.7/44.8 MB 9.5 MB/s eta 0:00:03
#    -------------------- ------------------- 23.0/44.8 MB 8.8 MB/s eta 0:00:03
#    --------------------- ------------------ 23.8/44.8 MB 8.7 MB/s eta 0:00:03
#    --------------------- ------------------ 24.6/44.8 MB 9.0 MB/s eta 0:00:03
#    ---------------------- ----------------- 25.3/44.8 MB 9.0 MB/s eta 0:00:03
#    ----------------------- ---------------- 26.0/44.8 MB 9.0 MB/s eta 0:00:03
#    ----------------------- ---------------- 26.8/44.8 MB 9.0 MB/s eta 0:00:03
#    ------------------------ --------------- 27.6/44.8 MB 9.2 MB/s eta 0:00:02
#    ------------------------ --------------- 28.0/44.8 MB 9.0 MB/s eta 0:00:02
#    ------------------------- -------------- 28.6/44.8 MB 9.0 MB/s eta 0:00:02
#    -------------------------- ------------- 29.4/44.8 MB 9.0 MB/s eta 0:00:02
#    -------------------------- ------------- 30.2/44.8 MB 9.0 MB/s eta 0:00:02
#    --------------------------- ------------ 30.9/44.8 MB 9.1 MB/s eta 0:00:02
#    ---------------------------- ----------- 31.7/44.8 MB 9.0 MB/s eta 0:00:02
#    ---------------------------- ----------- 32.5/44.8 MB 9.0 MB/s eta 0:00:02
#    ----------------------------- ---------- 33.1/44.8 MB 11.7 MB/s eta 0:00:02
#    ------------------------------ --------- 33.6/44.8 MB 11.7 MB/s eta 0:00:01
#    ------------------------------ --------- 34.3/44.8 MB 11.7 MB/s eta 0:00:01
#    ------------------------------- -------- 34.8/44.8 MB 11.7 MB/s eta 0:00:01
#    ------------------------------- -------- 35.3/44.8 MB 11.7 MB/s eta 0:00:01
#    -------------------------------- ------- 35.9/44.8 MB 11.9 MB/s eta 0:00:01
#    -------------------------------- ------- 36.5/44.8 MB 11.7 MB/s eta 0:00:01
#    --------------------------------- ------ 37.3/44.8 MB 11.9 MB/s eta 0:00:01
#    --------------------------------- ------ 37.9/44.8 MB 11.9 MB/s eta 0:00:01
#    ---------------------------------- ----- 38.4/44.8 MB 12.4 MB/s eta 0:00:01
#    ---------------------------------- ----- 38.9/44.8 MB 12.4 MB/s eta 0:00:01
#    ----------------------------------- ---- 39.5/44.8 MB 12.1 MB/s eta 0:00:01
#    ----------------------------------- ---- 40.0/44.8 MB 12.1 MB/s eta 0:00:01
#    ------------------------------------ --- 40.7/44.8 MB 12.1 MB/s eta 0:00:01
#    ------------------------------------ --- 41.2/44.8 MB 12.4 MB/s eta 0:00:01
#    ------------------------------------- -- 41.9/44.8 MB 12.4 MB/s eta 0:00:01
#    ------------------------------------- -- 42.4/44.8 MB 12.4 MB/s eta 0:00:01
#    -------------------------------------- - 43.0/44.8 MB 12.1 MB/s eta 0:00:01
#    -------------------------------------- - 43.6/44.8 MB 12.4 MB/s eta 0:00:01
#    ---------------------------------------  44.2/44.8 MB 12.1 MB/s eta 0:00:01
#    ---------------------------------------  44.7/44.8 MB 12.4 MB/s eta 0:00:01
#    ---------------------------------------  44.8/44.8 MB 12.3 MB/s eta 0:00:01
#    ---------------------------------------  44.8/44.8 MB 12.3 MB/s eta 0:00:01
#    ---------------------------------------  44.8/44.8 MB 12.3 MB/s eta 0:00:01
#    ---------------------------------------  44.8/44.8 MB 12.3 MB/s eta 0:00:01
#    ---------------------------------------  44.8/44.8 MB 12.3 MB/s eta 0:00:01
#    ---------------------------------------  44.8/44.8 MB 12.3 MB/s eta 0:00:01
#    ---------------------------------------  44.8/44.8 MB 12.3 MB/s eta 0:00:01
#    ---------------------------------------  44.8/44.8 MB 12.3 MB/s eta 0:00:01
#    ---------------------------------------  44.8/44.8 MB 12.3 MB/s eta 0:00:01
#    ---------------------------------------  44.8/44.8 MB 12.3 MB/s eta 0:00:01
#    ---------------------------------------  44.8/44.8 MB 12.3 MB/s eta 0:00:01
#    ---------------------------------------  44.8/44.8 MB 12.3 MB/s eta 0:00:01
#    ---------------------------------------  44.8/44.8 MB 12.3 MB/s eta 0:00:01
#    ---------------------------------------  44.8/44.8 MB 12.3 MB/s eta 0:00:01
#    ---------------------------------------  44.8/44.8 MB 12.3 MB/s eta 0:00:01
#    ---------------------------------------  44.8/44.8 MB 12.3 MB/s eta 0:00:01
#    ---------------------------------------  44.8/44.8 MB 12.3 MB/s eta 0:00:01
#    ---------------------------------------- 44.8/44.8 MB 6.2 MB/s eta 0:00:00
# Installing collected packages: flatbuffers, protobuf, opencv-contrib-python, absl-py, sounddevice, mediapipe
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'E:\\major-project\\environ\\Lib\\site-packages\\cv2\\cv2.pyd'
# Check the permissions.

# %%
import mediapipe as mp
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 import mediapipe as mp
#
# ModuleNotFoundError: No module named 'mediapipe'

# %%
import mediapipe as mp
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 import mediapipe as mp
#
# ModuleNotFoundError: No module named 'mediapipe'
